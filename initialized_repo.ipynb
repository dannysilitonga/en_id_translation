# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# %cd drive/MyDrive/offline/Github/en_id_translation
# Out:
# /content/drive/MyDrive/offline/Github/en_id_translation

# %%
# !git config --global user.email dsilitonga@gradcenter.cuny.edu
# !git config --global user.name dannysilitonga

# %%
# !git config --global user.password <Enter your Password here>

# %%
username = 'dannysilitonga'
git_token = <Enter your token here>
repository = 'en_id_translation'

# %%
# !git remote rm origin

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git

# %%
#!git remote -v

# %%
# !git push -u origin master
# Out:
# Counting objects: 3, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 740 bytes | 246.00 KiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0)
# To https://github.com/dannysilitonga/en_id_translation.git
#  * [new branch]      master -> master
# Branch 'master' set up to track remote branch 'master' from 'origin'.

# %%
import os
from getpass import getpass
import urllib

# %%
password = getpass('RKgMKytjW03I9y%VadHf')
reo_
